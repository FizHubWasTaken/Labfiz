# %% [markdown]
# <a href="https://colab.research.google.com/github/FizHubWasTaken/Labfiz/blob/main/MateuszWleklinski/41Busola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from math import pi

# %%
def rad(deg):
  return deg * pi / 180

# %%
labels = [
          'lp',
          'Liczba zwojów',
          'Prąd I [A]',
          'Zakres Amperomierza [A]',
          'Kąt wychylenia w lewo [stopnie]',
          'Kąt wychylenia w prawo [stopnie]',
]
lp = [i for i in range(1, 24)]
zwoje = [float(item) for item in """40
40
40
40
40
40
36
36
36
36
36
24
24
24
24
24
12
12
12
12
16
16
16""".split("\n")]
prad = [float(item.replace(",", ".")) for item in """0,09
0,215
0,18
0,14
0,115
0,061
0,09
0,114
0,142
0,18
0,22
0,35
0,27
0,185
0,14
0,092
0,28
0,39
0,52
0,69
0,5
0,37
0,185""".split("\n")]
zakres = [float(item.replace(",", ".")) for item in """0,3
0,3
0,3
0,3
0,3
0,075
0,15
0,15
0,15
0,3
0,3
0,75
0,75
0,3
0,3
0,15
0,3
0,75
0,75
0,75
0,75
0,75
0,3""".split("\n")]
katLewo = [float(item.replace(",", ".")) for item in """39
59
56
48
43
28
36
41
47
53
62
59
53
41
36
26
34
43
51
58
59
51
0,33""".split("\n")]
katPrawo = [float(item.replace(",", ".")) for item in """41
64
59
52
45
27
36
41,5
50
57
59
63
58
45
37
27
36
46
55
62
62
54
34""".split("\n")]

# %%
dict = {}
for i, item in enumerate([lp, zwoje, prad, zakres, katLewo, katPrawo ]):
  dict[labels[i]] = item
tab = pd.DataFrame(dict)

# %%
tab
# Out:
#     lp  ...  Kąt wychylenia w prawo [stopnie]
# 0    1  ...                              41.0
# 1    2  ...                              64.0
# 2    3  ...                              59.0
# 3    4  ...                              52.0
# 4    5  ...                              45.0
# 5    6  ...                              27.0
# 6    7  ...                              36.0
# 7    8  ...                              41.5
# 8    9  ...                              50.0
# 9   10  ...                              57.0
# 10  11  ...                              59.0
# 11  12  ...                              63.0
# 12  13  ...                              58.0
# 13  14  ...                              45.0
# 14  15  ...                              37.0
# 15  16  ...                              27.0
# 16  17  ...                              36.0
# 17  18  ...                              46.0
# 18  19  ...                              55.0
# 19  20  ...                              62.0
# 20  21  ...                              62.0
# 21  22  ...                              54.0
# 22  23  ...                              34.0
#
# [23 rows x 6 columns]

# %%
tab['Średni kąt nachylenia [rad]'] = rad((tab['Kąt wychylenia w lewo [stopnie]'] + tab['Kąt wychylenia w prawo [stopnie]']) / 2)

# %%
tab
# Out:
#     lp  ...  Średni kąt nachylenia [rad]
# 0    1  ...                     0.698132
# 1    2  ...                     1.073377
# 2    3  ...                     1.003564
# 3    4  ...                     0.872665
# 4    5  ...                     0.767945
# 5    6  ...                     0.479966
# 6    7  ...                     0.628319
# 7    8  ...                     0.719948
# 8    9  ...                     0.846485
# 9   10  ...                     0.959931
# 10  11  ...                     1.055924
# 11  12  ...                     1.064651
# 12  13  ...                     0.968658
# 13  14  ...                     0.750492
# 14  15  ...                     0.637045
# 15  16  ...                     0.462512
# 16  17  ...                     0.610865
# 17  18  ...                     0.776672
# 18  19  ...                     0.925025
# 19  20  ...                     1.047198
# 20  21  ...                     1.055924
# 21  22  ...                     0.916298
# 22  23  ...                     0.299586
#
# [23 rows x 7 columns]
